# %%
tensorboard --logdir logs/fit
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_21512/213534274.py", line 1
#     tensorboard --logdir logs/fit
#                             ^
# SyntaxError: invalid syntax

# %%
# %tensorboard --logdir logs/fit
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 0.14.1
# anyio                   3.3.2
# argcomplete             1.12.3
# argon2-cffi             21.1.0
# astunparse              1.6.3
# attrs                   21.2.0
# Babel                   2.9.1
# backcall                0.2.0
# bleach                  4.1.0
# cached-property         1.5.2
# cachetools              4.2.4
# certifi                 2021.5.30
# cffi                    1.14.6
# charset-normalizer      2.0.6
# clang                   5.0
# colorama                0.4.4
# cycler                  0.10.0
# debugpy                 1.5.0
# decorator               5.1.0
# defusedxml              0.7.1
# entrypoints             0.3
# flatbuffers             1.12
# gast                    0.4.0
# google-auth             1.35.0
# google-auth-oauthlib    0.4.6
# google-pasta            0.2.0
# grpcio                  1.41.0
# h5py                    3.1.0
# ...

# %%
pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 0.14.1
# anyio                   3.3.2
# argcomplete             1.12.3
# argon2-cffi             21.1.0
# astunparse              1.6.3
# attrs                   21.2.0
# Babel                   2.9.1
# backcall                0.2.0
# bleach                  4.1.0
# cached-property         1.5.2
# cachetools              4.2.4
# certifi                 2021.5.30
# cffi                    1.14.6
# charset-normalizer      2.0.6
# clang                   5.0
# colorama                0.4.4
# cycler                  0.10.0
# debugpy                 1.5.0
# decorator               5.1.0
# defusedxml              0.7.1
# entrypoints             0.3
# flatbuffers             1.12
# gast                    0.4.0
# google-auth             1.35.0
# google-auth-oauthlib    0.4.6
# google-pasta            0.2.0
# grpcio                  1.41.0
# h5py                    3.1.0
# ...
